# %%
import lime
import matplotlib.pyplot as plt
from lime import lime_image
import numpy as np
from skimage.segmentation import mark_boundaries
import skimage
from skimage.segmentation import slic

from captum.attr import Saliency
from captum.attr import IntegratedGradients

import torchvision.transforms as T

import torch 
from torchvision import datasets, transforms
transform = transforms.ToTensor()
test_dataset = datasets.MNIST(root="../data", train=False, download=True, transform=transform)

# %%
# load the model by An et al. (2020)
from Models.modelM5 import ModelM5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ModelM5().to(device)
model.load_state_dict(torch.load("Models/model004.pth"))
model.eval()
# Out:
# C:\Users\merli\AppData\Local\Temp\ipykernel_12848\260027207.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("Models/model004.pth"))
# ...

# %% [markdown]
# ### Applying the model on a datapoint

# %%
number = 4  # change for a different image

# %%
# load an image form the MNIST dataset
image_unproc, label = test_dataset[number]

plt.imshow(image_unproc.squeeze(0), cmap="gray")

# add another dimension, this way the model can process the image
image_proc = image_unproc.unsqueeze(0).to(device)

# add Gaussian blur to the image
blur = T.GaussianBlur(kernel_size=5, sigma=1.5)
image_proc = blur(image_proc)

# predict the label
output = model(image_proc)
pred = output.argmax(dim=1)


plt.imshow(image_proc.squeeze().cpu(), cmap="gray")
plt.title(f"prediction = {pred.item()}\nlabel = {label}")
plt.savefig(f"images/regular image blur {number}")
plt.show()

# %% [markdown]
# ### LIME

# %%
# LIME
explainer = lime_image.LimeImageExplainer()

# %%
# convert image to rgb and to numpy, this is required for LIME
image_numpy = image_proc.squeeze(0).cpu().numpy()
image_rgb = np.repeat(image_numpy.squeeze(0)[:, :, np.newaxis], 3, axis=2)

# %%
def model_for_lime(image):
    """
    Takes a numpy image, turns it into a torch image, predicts the probabilities using the model. 
    :param image: MNIST image
    :return: probabilities of the image belonging to which class as a numpy array
    """
    # turn into grayscale again
    batch = torch.from_numpy(np.mean(image, axis=3, keepdims=True)).permute(0, 3, 1, 2).float()
    batch = batch.to(device)
    
    #predict probs
    with torch.no_grad():
        probs = torch.softmax(model(batch), dim=1)
    return probs.cpu().numpy()


def smaller_segments(image):
    """
    Allows LIME to have more segments on a small image
    :param image: MNIST image
    :return: how manny segments in the explanation 
    """
    return slic(image, n_segments = 20)

# %%
# create explanation
explanation = explainer.explain_instance(image_rgb, model_for_lime, top_labels= 1,  num_samples=1000, segmentation_fn=smaller_segments)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# All superpixels
skimage.io.imshow(skimage.segmentation.mark_boundaries(image_rgb, explanation.segments, mode="subpixel"))
plt.title(f"LIME superpixels \n Nb of superpixels {len(np.unique(explanation.segments))}")
plt.savefig(f"images/superpixel image blur {number}")
plt.show()
# Out:
# C:\Users\merli\AppData\Local\Temp\ipykernel_12848\1473394326.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   skimage.io.imshow(skimage.segmentation.mark_boundaries(image_rgb, explanation.segments, mode="subpixel"))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0055023567..1.0].

# %%
# plot the 3 most important superpixels according to LIME
temp, mask = explanation.get_image_and_mask(label, positive_only=False, num_features=3, hide_rest=False)
plt.imshow(mark_boundaries(temp, mask))
plt.savefig(f"images/3superpixel image blur {number}")
plt.title(f"LIME top 3 most important pixels")
plt.show()

# %% [markdown]
# ### Vanilla gradients and Integrated Gradients

# %%
saliency = Saliency(model)

#compute saliency map
sal_map = saliency.attribute(image_proc, target=pred.item()).squeeze().cpu().detach().numpy()
# Out:
# C:\Users\merli\Documents\MnistSimpleCNN\.venv\Lib\site-packages\captum\attr\_core\saliency.py:129: UserWarning: Input Tensor 0 did not already require gradients, required_grads has been set automatically.
#   gradient_mask = apply_gradient_requirements(inputs_tuple)

# %%
plt.imshow(sal_map, cmap= "gray")
plt.title(f"Vanilla gradient")
plt.savefig(f"images/vanilla gradient blur {number}")
plt.show()

# %%
# integrated gradients
ig = IntegratedGradients(model)
image_attr, delta = ig.attribute(image_proc, n_steps=100, target=label, return_convergence_delta=True)

# %%
plt.imshow(image_attr.squeeze().cpu().detach().numpy(), cmap= "gray")
plt.title(f"Integrated gradient")
plt.savefig(f"images/Integrated gradient blur {number}")
plt.show()
